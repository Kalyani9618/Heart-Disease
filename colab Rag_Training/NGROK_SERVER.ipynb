# %%
# !pip install flask pyngrok transformers torch torchvision pillow accelerate huggingface_hub

# %%
from google.colab import drive
import os

# Change directory to where you uploaded your Python files
# UPDATE THIS PATH to match your actual folder structure
os.chdir('/content/drive/MyDrive/IDP/Medical/Coding')

# Verify the files are there
# !ls
# Out:
# AUDIT_REPORT.md		 embedding_colab.py	     REMOTE_EMBEDDINGS_GUIDE.md
# colab_server.py		 __pycache__		     remote_embeddings.py
# COMPATIBILITY_REPORT.md  rag_integration_example.py  requirements.txt
# config.py		 rag_pipeline.py	     SETUP_COMPLETE.md
# data_ingestion.py	 RAG_TRAINING.ipynb	     test_remote_embeddings.py

# %%
import os
from colab_server import start_server

# Set your ngrok token
os.environ["NGROK_AUTH_TOKEN"] = "YOUR_NGROK_AUTH_TOKEN_HERE"

# Start the server. We are setting preload_medgemma=False to only load the TWO models you requested.
start_server(
    port=5000,
    preload_medcpt=True,   # Loads text embedding model
    preload_siglip=False,   # Loads image embedding model
    preload_medgemma=False # Set to True if you also want text generation
)
# Out:
# Loading weights:   0%|          | 0/199 [00:02<?, ?it/s]
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# 🔗 COLAB_API_URL=https://unilludedly-pipier-paola.ngrok-free.dev
#
#  * Serving Flask app 'colab_server'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [08/Mar/2026 15:57:37] "GET /health HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [08/Mar/2026 15:57:46] "GET /health HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [08/Mar/2026 15:57:48] "POST /embed_text HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [08/Mar/2026 15:57:49] "POST /embed_text HTTP/1.1" 200 -
# ...
